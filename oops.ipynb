# %%
# Class
# -> Creating class

class student :
    name = 'krishna'
# -> Creating object 

s1= student()
print (s1.name)

# %%
# -> Class examples 
class car :
    color = 'red'
    engine = ' v8'
    

car1 = car()
print (car.color)
# Out:
# red

# %%
#n -> constructors
class School :
    def __init__(self, fullname):
        self.name = fullname
